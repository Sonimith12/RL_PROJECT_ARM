# %%
# !git clone https://github.com/Sonimith12/RL_PROJECT_ARM.git
# Out:
# Cloning into 'RL_PROJECT_ARM'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 134 (delta 72), reused 82 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (134/134), 5.82 MiB | 22.08 MiB/s, done.
# Resolving deltas: 100% (72/72), done.

# %%
# %cd RL_PROJECT_ARM/
# !ls
# Out:
# /content/RL_PROJECT_ARM
# arm_model.py	       logs	   __pycache__	requirements.txt       Utils.py
# exponential_reward.py  models	   README.md	tempCodeRunnerFile.py
# load_model.py	       new_models  Renderer.py	train_model.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 84.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 104.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 52.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...

# %%
# !python train_model.py --use-gpu --episode-length 2500 --total-timesteps 250000
# Out:
# 2025-03-02 20:55:15.676698: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740948915.723045    6003 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740948915.734216    6003 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-02 20:55:15.769253: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %cd RL_PROJECT_ARM/
# !ls
# Out:
# [Errno 2] No such file or directory: 'RL_PROJECT_ARM/'
# /content/RL_PROJECT_ARM/RL_PROJECT_ARM
# arm_model.py   logs    __pycache__  Renderer.py       tempCodeRunnerFile.py  Utils.py
# load_model.py  models  README.md    requirements.txt  train_model.py

# %%
# %cd /content/RL_PROJECT_ARM/
# Out:
# /content/RL_PROJECT_ARM

# %%
# !git pull
# Out:
# Updating d3c9523..09b0105
# error: The following untracked working tree files would be overwritten by merge:
# 	models/sac_arm.zip
# Please move or remove them before you merge.
# Aborting

# %%
# !python load_model.py --model-path models/sac_arm.zip --no-render --eval-steps 7000
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 2025-03-02 21:21:14,894 - INFO - Step: 2004, Reward: 109.5336
# 2025-03-02 21:21:14,896 - INFO - Step: 2005, Reward: 109.5336
# 2025-03-02 21:21:14,897 - INFO - Step: 2006, Reward: 109.5336
# 2025-03-02 21:21:14,899 - INFO - Step: 2007, Reward: 109.5336
# 2025-03-02 21:21:14,900 - INFO - Step: 2008, Reward: 109.5336
# 2025-03-02 21:21:14,902 - INFO - Step: 2009, Reward: 109.5336
# 2025-03-02 21:21:14,903 - INFO - Step: 2010, Reward: 109.5336
# 2025-03-02 21:21:14,905 - INFO - Step: 2011, Reward: 109.5336
# 2025-03-02 21:21:14,906 - INFO - Step: 2012, Reward: 109.5336
# 2025-03-02 21:21:14,907 - INFO - Step: 2013, Reward: 109.5336
# 2025-03-02 21:21:14,909 - INFO - Step: 2014, Reward: 109.5336
# 2025-03-02 21:21:14,910 - INFO - Step: 2015, Reward: 109.5336
# 2025-03-02 21:21:14,912 - INFO - Step: 2016, Reward: 109.5336
# 2025-03-02 21:21:14,913 - INFO - Step: 2017, Reward: 109.5336
# ...
